# %% [markdown]
# # MongoDB
#
# Based on https://docs.mongodb.com/getting-started

# %% [markdown]
# MongoDB is a **NoSQL** open-source **document database**.  MongoDB provides horizontal scaling by replicating and partitioning the data over multiple nodes. This can improve the reliability and scalability of the system.
#
# A record in MongoDB is a **document**, which is a data structure composed of field and value pairs. MongoDB documents are similar to JSON objects or Python dictionaries. The values of fields may include other documents, arrays, and arrays of documents.
#
# This is an example of a document:
# ```JSON
# {
#    "_id" : ObjectId("54c955492b7c8eb21818bd09"),
#    "address" : {
#       "street" : "2 Avenue",
#       "zipcode" : "10075",
#       "building" : "1480",
#       "coord" : [ -73.9557413, 40.7720266 ]
#    },
#    "borough" : "Manhattan",
#    "cuisine" : "Italian",
#    "grades" : [
#       {
#          "date" : ISODate("2014-10-01T00:00:00Z"),
#          "grade" : "A",
#          "score" : 11
#       },
#       {
#          "date" : ISODate("2014-01-16T00:00:00Z"),
#          "grade" : "B",
#          "score" : 17
#       }
#    ],
#    "name" : "Vella",
#    "restaurant_id" : "41704620"
# }
# ```
# In MongoDB, documents have a unique **_id** field that acts as a primary key. MongoDB automatically adds a unique _id to each document if you are not providing it by yourself.
#
# MongoDB stores documents in **collections**. Collections are analogous to tables in relational databases. Unlike a table, however, a collection does not require its documents to have the same schema.
#
# You can start a Docker image with MongoDB like this:
# ```bash
# docker run -p 27017:27017 -d mongo
# ```
#
# In production you really (!) would need to enable authentication with username and password, but for development purposes this is fine.

# %%
# Install the pymongo Python Package 
# !pip3 install pymongo

# %%
from pymongo import MongoClient
from pprint import pprint
import requests

# %% [markdown]
# Use MongoClient to create a connection. If you do not specify any arguments to MongoClient, then MongoClient defaults to the MongoDB instance that runs on the localhost interface on port 27017. You can also specify a complete MongoDB URI to define the connection, including explicitly specifying the host and port number. For example, the following creates a connection to a MongoDB instance that runs on mongodb0.example.net and the port of 27017: client = MongoClient("mongodb://mongodb0.example.net:27017")

# %%
# Client connects to "localhost" by default 
client = MongoClient()

# %% [markdown]
# The first fundamental class of objects you will interact with using pymongo is Database which represents the database construct in MongoDB. Databases hold groups of logically related collections. MongoDB creates new databases implicitly upon their first use. Connect (create) with a database of your name, e.g.
#
# ```python
# db = client["rolandmueller"]
# ```
# or
#
# ```python
# db = client.rolandmueller
# ```

# %%
# Create local "bipm" database on the fly 
db = client['bipm']

# %%
# When we rerun the whole notebook, we start from scratch 
# by dropping the colection "courses"
db.courses.drop()

# %%
# Create a Python Dictonary
courses = [
    {'title': 'Data Science',
     'lecturer': {
         'name': 'Markus Löcher',
         'department': 'Math',
         'status': 'Professor'
     },
     'semester': 1},
    {'title': 'Data Warehousing',
     'lecturer': {
         'name': 'Roland M. Mueller',
         'department': 'Information Systems',
         'status': 'Professor'
     },
     'semester': 1},
    {'title': 'Business Process Management',
     'lecturer': {
         'name': 'Frank Habermann',
         'department': 'Information Systems',
         'status': 'Professor'
     },
     'semester': 1},
    {'title': 'Stratigic Issues of IT',
     'lecturer': {
         'name': 'Sven Pohland',
         'department': 'Information Systems',
         'status': 'Professor'
     },
     'semester': 1},
    {'title': 'Text, Web and Social Media Analytics Lab',
     'lecturer': {
         'name': 'Markus Löcher',
         'department': 'Math',
         'status': 'Professor'
     },
     'semester': 2},
    {'title': 'Enterprise Architectures for Big Data',
     'lecturer': {
         'name': 'Roland M. Mueller',
         'department': 'Information Systems',
         'status': 'Professor'
     },
     'semester': 2},
    {'title': 'Business Process Integration Lab',
     'lecturer': {
         'name': 'Frank Habermann',
         'department': 'Information Systems',
         'status': 'Professor'
     },
     'semester': 2},
    {'title': 'IT-Security and Privacy',
     'lecturer': {
         'name': 'Dennis Uckel',
         'department': 'Information Systems',
         'status': 'External'
     },
     'semester': 2},
    {'title': 'Research Methods',
     'lecturer': {
         'name': 'Marcus Birkenkrahe',
         'department': 'Information Systems',
         'status': 'Professor'
     },
     'semester': 2},
]

# %%
pprint(courses)
# Out:
# [{'lecturer': {'department': 'Math',
#                'name': 'Markus Löcher',
#                'status': 'Professor'},
#   'semester': 1,
#   'title': 'Data Science'},
#  {'lecturer': {'department': 'Information Systems',
#                'name': 'Roland M. Mueller',
#                'status': 'Professor'},
#   'semester': 1,
#   'title': 'Data Warehousing'},
#  {'lecturer': {'department': 'Information Systems',
#                'name': 'Frank Habermann',
#                'status': 'Professor'},
#   'semester': 1,
#   'title': 'Business Process Management'},
#  {'lecturer': {'department': 'Information Systems',
#                'name': 'Sven Pohland',
#                'status': 'Professor'},
#   'semester': 1,
#   'title': 'Stratigic Issues of IT'},
#  {'lecturer': {'department': 'Math',
#                'name': 'Markus Löcher',
#                'status': 'Professor'},
#   'semester': 2,
#   'title': 'Text, Web and Social Media Analytics Lab'},
#  {'lecturer': {'department': 'Information Systems',
#                'name': 'Roland M. Mueller',
#                'status': 'Professor'},
#   'semester': 2,
#   'title': 'Enterprise Architectures for Big Data'},
#  {'lecturer': {'department': 'Information Systems',
#                'name': 'Frank Habermann',
#                'status': 'Professor'},
#   'semester': 2,
#   'title': 'Business Process Integration Lab'},
#  {'lecturer': {'department': 'Information Systems',
#                'name': 'Dennis Uckel',
#                'status': 'External'},
#   'semester': 2,
#   'title': 'IT-Security and Privacy'},
#  {'lecturer': {'department': 'Information Systems',
#                'name': 'Marcus Birkenkrahe',
#                'status': 'Professor'},
#   'semester': 2,
#   'title': 'Research Methods'}]

# %% [markdown]
# ## insert_many()
#
# You can use the `insert_one()` method and the `insert_many()` method to add documents to a collection in MongoDB. If you attempt to add documents to a collection that does not exist, MongoDB will create the collection for you.

# %%
db.courses.insert_many(courses)

# %% [markdown]
# ## find()
#
# You can use the find() method to issue a query to retrieve data from a collection in MongoDB. All queries in MongoDB have the scope of a single collection.
# Queries can return all documents in a collection or only the documents that match a specified filter or criteria. You can specify the filter or criteria in a document and pass as a parameter to the find() method. With no parameter, find() returns all documents in the collection.
#
# The find() method returns query results in a cursor, which is an iterable object that yields documents. Then you can print all documents.
#
# ```python
# cursor = db.my_collection.find()
#
# for document in cursor:
#     pprint(document)
# ```

# %%
# TODO: Print all courses

cours_list= db.courses.find()

for document in cours_list:
    pprint(document)
# Out:
# {'_id': ObjectId('5ed5316cff2a824fbb2b3855'),
#  'lecturer': {'department': 'Math',
#               'name': 'Markus Löcher',
#               'status': 'Professor'},
#  'semester': 1,
#  'title': 'Data Science'}
# {'_id': ObjectId('5ed5316cff2a824fbb2b3856'),
#  'lecturer': {'department': 'Information Systems',
#               'name': 'Roland M. Mueller',
#               'status': 'Professor'},
#  'semester': 1,
#  'title': 'Data Warehousing'}
# {'_id': ObjectId('5ed5316cff2a824fbb2b3857'),
#  'lecturer': {'department': 'Information Systems',
#               'name': 'Frank Habermann',
#               'status': 'Professor'},
#  'semester': 1,
#  'title': 'Business Process Management'}
# {'_id': ObjectId('5ed5316cff2a824fbb2b3858'),
#  'lecturer': {'department': 'Information Systems',
#               'name': 'Sven Pohland',
#               'status': 'Professor'},
#  'semester': 1,
#  'title': 'Stratigic Issues of IT'}
# {'_id': ObjectId('5ed5316cff2a824fbb2b3859'),
#  'lecturer': {'department': 'Math',
#               'name': 'Markus Löcher',
#               'status': 'Professor'},
#  'semester': 2,
#  'title': 'Text, Web and Social Media Analytics Lab'}
# {'_id': ObjectId('5ed5316cff2a824fbb2b385a'),
#  'lecturer': {'department': 'Information Systems',
#               'name': 'Roland M. Mueller',
#               'status': 'Professor'},
#  'semester': 2,
#  'title': 'Enterprise Architectures for Big Data'}
# {'_id': ObjectId('5ed5316cff2a824fbb2b385b'),
#  'lecturer': {'department': 'Information Systems',
#               'name': 'Frank Habermann',
#               'status': 'Professor'},
#  'semester': 2,
#  'title': 'Business Process Integration Lab'}
# {'_id': ObjectId('5ed5316cff2a824fbb2b385c'),
#  'lecturer': {'department': 'Information Systems',
#               'name': 'Dennis Uckel',
#               'status': 'External'},
#  'semester': 2,
#  'title': 'IT-Security and Privacy'}
# {'_id': ObjectId('5ed5316cff2a824fbb2b385d'),
#  'lecturer': {'department': 'Information Systems',
#               'name': 'Marcus Birkenkrahe',
#               'status': 'Professor'},
#  'semester': 2,
#  'title': 'Research Methods'}

# %% [markdown]
# ## JSON
#
# You can store a JSON document if you convert it before to a Python dictionary:

# %%
import json
my_json = '{"title": "Master Thesis", "semester": 3}'
another_course = json.loads(my_json)
another_course
# Out:
# {'title': 'Master Thesis', 'semester': 3}

# %% [markdown]
# ## insert_one()
#
# The `insert_one()` method adds the document into the collection.

# %%
# TODO: Store `another_course` as another course:
db.courses.insert_one(another_course)

# %%
# TODO: Print all 
cours_list= db.courses.find()

for document in cours_list:
    pprint(document)
# Out:
# {'_id': ObjectId('5ed5316cff2a824fbb2b3855'),
#  'lecturer': {'department': 'Math',
#               'name': 'Markus Löcher',
#               'status': 'Professor'},
#  'semester': 1,
#  'title': 'Data Science'}
# {'_id': ObjectId('5ed5316cff2a824fbb2b3856'),
#  'lecturer': {'department': 'Information Systems',
#               'name': 'Roland M. Mueller',
#               'status': 'Professor'},
#  'semester': 1,
#  'title': 'Data Warehousing'}
# {'_id': ObjectId('5ed5316cff2a824fbb2b3857'),
#  'lecturer': {'department': 'Information Systems',
#               'name': 'Frank Habermann',
#               'status': 'Professor'},
#  'semester': 1,
#  'title': 'Business Process Management'}
# {'_id': ObjectId('5ed5316cff2a824fbb2b3858'),
#  'lecturer': {'department': 'Information Systems',
#               'name': 'Sven Pohland',
#               'status': 'Professor'},
#  'semester': 1,
#  'title': 'Stratigic Issues of IT'}
# {'_id': ObjectId('5ed5316cff2a824fbb2b3859'),
#  'lecturer': {'department': 'Math',
#               'name': 'Markus Löcher',
#               'status': 'Professor'},
#  'semester': 2,
#  'title': 'Text, Web and Social Media Analytics Lab'}
# {'_id': ObjectId('5ed5316cff2a824fbb2b385a'),
#  'lecturer': {'department': 'Information Systems',
#               'name': 'Roland M. Mueller',
#               'status': 'Professor'},
#  'semester': 2,
#  'title': 'Enterprise Architectures for Big Data'}
# {'_id': ObjectId('5ed5316cff2a824fbb2b385b'),
#  'lecturer': {'department': 'Information Systems',
#               'name': 'Frank Habermann',
#               'status': 'Professor'},
#  'semester': 2,
#  'title': 'Business Process Integration Lab'}
# {'_id': ObjectId('5ed5316cff2a824fbb2b385c'),
#  'lecturer': {'department': 'Information Systems',
#               'name': 'Dennis Uckel',
#               'status': 'External'},
#  'semester': 2,
#  'title': 'IT-Security and Privacy'}
# {'_id': ObjectId('5ed5316cff2a824fbb2b385d'),
#  'lecturer': {'department': 'Information Systems',
#               'name': 'Marcus Birkenkrahe',
#               'status': 'Professor'},
#  'semester': 2,
#  'title': 'Research Methods'}
# {'_id': ObjectId('5ed53232ff2a824fbb2b385e'),
#  'semester': 3,
#  'title': 'Master Thesis'}

# %% [markdown]
# ## find_one() and find()
#
# `find_one()` returns the first match. ```find()```returns all matches.
#
# The query condition for `find_one()` and `find()` for an equality match on fields has the following form:
# ```python
# { <field1>: <value1>, <field2>: <value2>, ... }
# ```
#
# The following operation finds the first documents whose name field equals "Manhattan".
#
# ```python
# cursor = db.restaurants.find_one({"name": "Manhattan"})
# ```

# %%
# TODO: Find the course with the title "Data Science" 
result=db.courses.find_one({"title": "Data Science"})

pprint(result)

# save the result in a varibale result
# and pprint the result.
# Out:
# {'_id': ObjectId('5ed5316cff2a824fbb2b3855'),
#  'lecturer': {'department': 'Math',
#               'name': 'Markus Löcher',
#               'status': 'Professor'},
#  'semester': 1,
#  'title': 'Data Science'}

# %%
print(result["_id"])
print(result["lecturer"]["name"])
# Out:
# 5ed5316cff2a824fbb2b3855
# Markus Löcher

# %%
# TODO: Find the first course (one course) in the second semester
first=db.courses.find_one({"semester":2})
pprint(first)
# and print it
# Out:
# {'_id': ObjectId('5ed5316cff2a824fbb2b3859'),
#  'lecturer': {'department': 'Math',
#               'name': 'Markus Löcher',
#               'status': 'Professor'},
#  'semester': 2,
#  'title': 'Text, Web and Social Media Analytics Lab'}

# %%
# TODO: Find all courses in the second semester

all_second=db.courses.find({"semester":2})
for i in all_second:
    pprint(i["title"])
# and print the course titles

all_second
# Out:
# 'Text, Web and Social Media Analytics Lab'
# 'Enterprise Architectures for Big Data'
# 'Business Process Integration Lab'
# 'IT-Security and Privacy'
# 'Research Methods'

# %%
# TODO: Find all courses in the second semester

all_second_lecturers=db.courses.find({"semester":2})
for i in all_second_lecturers:
    pprint(i["lecturer"]["name"])
# and print the lecturers names
# Out:
# 'Markus Löcher'
# 'Roland M. Mueller'
# 'Frank Habermann'
# 'Dennis Uckel'
# 'Marcus Birkenkrahe'

# %% [markdown]
# ## Subelements
#
# Sometimes documents contains embedded documents as its elements. To specify a condition on a field in these documents, use the dot notation. Dot notation requires quotes around the whole dotted field name. The following queries for documents whose grades array contains an embedded document with a field grade equal to "B".
#
# ```python
# cursor = db.restaurants.find({"grades.grade": "B"})
# ```

# %%
# TODO: Find all courses of Frank Habermann
habermann=db.courses.find({"lecturer.name": "Frank Habermann"})
for i in habermann:
    pprint(i["title"])
    pprint(i["semester"])
# and print the title and the semester
# Out:
# 'Business Process Management'
# 1
# 'Business Process Integration Lab'
# 2

# %% [markdown]
# ## Logical AND
#
# You can specify a logical conjunction (AND) for a list of query conditions by separating the conditions with a comma in the conditions document.
#
# ```python
# cursor = db.restaurants.find({"cuisine": "Italian", "address.zipcode": "10075"})
# ```

# %%
# TODO: Find all courses from Frank Habermann in the second semester
habermann_second= db.courses.find({"lecturer.name": "Frank Habermann","semester":2})
for i in habermann_second:
    pprint(i["title"])
    pprint(i["semester"])
# and print the title and the semester
# Out:
# 'Business Process Integration Lab'
# 2

# %% [markdown]
# ## Logical OR
#
# You can specify a logical disjunction (OR) for a list of query conditions by using the $or query operator.
#
# ```python
# cursor = db.restaurants.find({"$or": [{"cuisine": "Italian"}, {"address.zipcode": "10075"}]})
# ```

# %%
# TODO: Find all courses from Frank Habermann or Markus Löcher
habermann_or_loecher=db.courses.find({"$or": [{"lecturer.name":"Frank Habermann"},{"lecturer.name":"Markus Löcher"}]})
for i in habermann_or_loecher:
    pprint(i["title"])
    pprint(i["semester"])
    
# and print the title and the semester
# Out:
# 'Data Science'
# 1
# 'Business Process Management'
# 1
# 'Text, Web and Social Media Analytics Lab'
# 2
# 'Business Process Integration Lab'
# 2

# %% [markdown]
# ## Greater than, Less than
#
# MongoDB provides operators to specify query conditions, such as comparison operators. Query conditions using operators generally have the following form:
# ```python
# { <field1>: { <operator1>: <value1> } }
# ```
#
# Greater Than Operator (`$gt`). Query for documents whose grades array contains an embedded document with a field score greater than 30.
#
# ```python
# cursor = db.restaurants.find({"grades.score": {"$gt": 30}})
# ```
#
# Less Than Operator (`$lt`). Query for documents whose grades array contains an embedded document with a field score less than 10.
#
# ```python
# cursor = db.restaurants.find({"grades.score": {"$lt": 10}})
# ```

# %%
# TODO: Find all courses in semester greater than 1
greater=db.courses.find({"semester":{"$gt":1}})
for i in greater:
    pprint(i["title"])
    pprint(i["semester"])
    
    
# and print the title and the semester
# Out:
# 'Text, Web and Social Media Analytics Lab'
# 2
# 'Enterprise Architectures for Big Data'
# 2
# 'Business Process Integration Lab'
# 2
# 'IT-Security and Privacy'
# 2
# 'Research Methods'
# 2
# 'Master Thesis'
# 3

# %% [markdown]
# ## Counting
#
# `count_documents()` works like `find()` but returns the number of matched documents-

# %%
# TODO: How many courses are in the second semester?

count_2=db.courses.count_documents({"semester":2})
pprint(count_2)
# Out:
# 5

# %% [markdown]
# # Downloading Nobel Prize Winners with an API and storing them in MongoDB
#
# ![](https://upload.wikimedia.org/wikipedia/en/e/ed/Nobel_Prize.png)
# The Nobel Prize offers a Web API https://nobelprize.readme.io/docs/prize
#
# Because the API is giving us JSON and MongoDB is able to store documents in a JSON-like format, using a document database like MongoDB seems like a good fit to store the results of the API.  You can get all laureates at http://api.nobelprize.org/v1/laureate.json and all prizes at http://api.nobelprize.org/v1/prize.json
#
# We will just download all laureates and prizes and store them in MongoDB!

# %%
# Create local "nobel" database on the fly 
db = client["nobel"]
db.prizes.drop()
db.laureates.drop()
# API documented at https://nobelprize.readme.io/docs/prize 
for collection_name in ["prizes", "laureates"]:
    singular = collection_name[:-1] # the API uses singular
    response = requests.get( "http://api.nobelprize.org/v1/{}.json".format(singular)) 
    documents = response.json()[collection_name] 
    # Create collections on the fly 
    db[collection_name].insert_many(documents)

# %%
pprint(db.laureates.find_one())
# Out:
# {'_id': ObjectId('5ed53712ff2a824fbb2b3ae5'),
#  'born': '1845-03-27',
#  'bornCity': 'Lennep (now Remscheid)',
#  'bornCountry': 'Prussia (now Germany)',
#  'bornCountryCode': 'DE',
#  'died': '1923-02-10',
#  'diedCity': 'Munich',
#  'diedCountry': 'Germany',
#  'diedCountryCode': 'DE',
#  'firstname': 'Wilhelm Conrad',
#  'gender': 'male',
#  'id': '1',
#  'prizes': [{'affiliations': [{'city': 'Munich',
#                                'country': 'Germany',
#                                'name': 'Munich University'}],
#              'category': 'physics',
#              'motivation': '"in recognition of the extraordinary services he '
#                            'has rendered by the discovery of the remarkable '
#                            'rays subsequently named after him"',
#              'share': '1',
#              'year': '1901'}],
#  'surname': 'Röntgen'}

# %%
# TODO: Print the first name of the first document
first_doc=db.laureates.find_one()
pprint(first_doc["firstname"])
# Out:
# 'Wilhelm Conrad'

# %% [markdown]
# With `count_documents` you can count the number of matching documents.

# %%
# How many female laureates exists? 
females=db.laureates.count_documents({"gender":"female"})
pprint(females)
# Out:
# 53

# %% [markdown]
# With the `$regex` function you can use a regular expression. `distinct` list only all distinct entries.

# %%
db.laureates.distinct("bornCountry", {"bornCountry": {"$regex": "Germany"}})
# Out:
# ['Bavaria (now Germany)',
#  'East Friesland (now Germany)',
#  'Germany',
#  'Germany (now France)',
#  'Germany (now Poland)',
#  'Germany (now Russia)',
#  'Hesse-Kassel (now Germany)',
#  'Mecklenburg (now Germany)',
#  'Prussia (now Germany)',
#  'Schleswig (now Germany)',
#  'West Germany (now Germany)',
#  'Württemberg (now Germany)']

# %%
# TODO: How many laureates are from Germany?

germans=db.laureates.count_documents({"bornCountry" : {"$regex": "Germany"}})
print(germans)
# Out:
# 95

# %%
# TODO: Find all physics nobel laureates that are from Germany

germans_physics=db.laureates.find({"bornCountry" : {"$regex": "Germany"},"prizes.category":"physics"})
for winner in germans_physics:
    #pprint(winner["prizes"]["year"])
    pprint(winner["firstname"])
    pprint(winner["surname"])
    #pprint(winner["prizes.year"])
           
# print the year of the first prize, the first name, and surename
# Out:
# 'Wilhelm Conrad'
# 'Röntgen'
# 'Ferdinand'
# 'Braun'
# 'Max'
# 'von Laue'
# 'Max'
# 'Planck'
# 'Johannes'
# 'Stark'
# 'Albert'
# 'Einstein'
# 'James'
# 'Franck'
# 'Gustav'
# 'Hertz'
# 'Werner'
# 'Heisenberg'
# 'Otto'
# 'Stern'
# 'Max'
# 'Born'
# 'Walther'
# 'Bothe'
# 'Polykarp'
# 'Kusch'
# 'Rudolf'
# 'Mössbauer'
# 'Maria'
# 'Goeppert Mayer'
# 'J. Hans D.'
# 'Jensen'
# 'Alfred'
# 'Kastler'
# 'Hans'
# 'Bethe'
# 'Arno'
# 'Penzias'
# 'Ernst'
# 'Ruska'
# 'Gerd'
# 'Binnig'
# 'J. Georg'
# 'Bednorz'
# 'Jack'
# 'Steinberger'
# 'Hans G.'
# 'Dehmelt'
# 'Wolfgang'
# 'Paul'
# 'Horst L.'
# 'Störmer'
# 'Herbert'
# 'Kroemer'
# 'Wolfgang'
# 'Ketterle'
# 'Theodor W.'
# 'Hänsch'
# 'Rainer'
# 'Weiss'

# %%
# TODO: find and print the document for "Malala" (firstname)


malala = db.laureates.find({"firstname":"Malala"})
for i in malala:
    pprint(i)
# Out:
# {'_id': ObjectId('5ed53712ff2a824fbb2b3e55'),
#  'born': '1997-07-12',
#  'bornCity': 'Mingora',
#  'bornCountry': 'Pakistan',
#  'bornCountryCode': 'PK',
#  'died': '0000-00-00',
#  'firstname': 'Malala',
#  'gender': 'female',
#  'id': '914',
#  'prizes': [{'affiliations': [[]],
#              'category': 'peace',
#              'motivation': '"for their struggle against the suppression of '
#                            'children and young people and for the right of all '
#                            'children to education"',
#              'share': '2',
#              'year': '2014'}],
#  'surname': 'Yousafzai'}

# %% [markdown]
# ## Sort()
#
# With `sort()` you can sort the list of documents. The parameter of sort is a list of sorting tuples. Each tuple is a value and an integer value 1 or -1 which states whether the collection to be sorted in ascending (1) or descending (-1) order.
#
# Sort all restaurants according to the grade in ascending order.
# ```python
# cursor = db.restaurants.find().sort([("grades.grade", 1)])
# ```

# %%
# TODO: Find only female nobel laureates 

females_sorted = db.laureates.find({"gender": "female"}).sort([("prizes.year", 1)])
for i in females_sorted:
    pprint(i)

# and sort them according the the prize year in ascending order
# print year of the first prize, firstname, and surename
# Out:
# {'_id': ObjectId('5ed53712ff2a824fbb2b3aea'),
#  'born': '1867-11-07',
#  'bornCity': 'Warsaw',
#  'bornCountry': 'Russian Empire (now Poland)',
#  'bornCountryCode': 'PL',
#  'died': '1934-07-04',
#  'diedCity': 'Sallanches',
#  'diedCountry': 'France',
#  'diedCountryCode': 'FR',
#  'firstname': 'Marie',
#  'gender': 'female',
#  'id': '6',
#  'prizes': [{'affiliations': [[]],
#              'category': 'physics',
#              'motivation': '"in recognition of the extraordinary services they '
#                            'have rendered by their joint researches on the '
#                            'radiation phenomena discovered by Professor Henri '
#                            'Becquerel"',
#              'share': '4',
#              'year': '1903'},
#             {'affiliations': [{'city': 'Paris',
#                                'country': 'France',
#                                'name': 'Sorbonne University'}],
#              'category': 'chemistry',
#              'motivation': '"in recognition of her services to the advancement '
#                            'of chemistry by the discovery of the elements '
#                            'radium and polonium, by the isolation of radium '
#                            'and the study of the nature and compounds of this '
#                            'remarkable element"',
#              'share': '1',
#              'year': '1911'}],
#  'surname': 'Curie'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3cb3'),
#  'born': '1843-06-09',
#  'bornCity': 'Prague',
#  'bornCountry': 'Austrian Empire (now Czech Republic)',
#  'bornCountryCode': 'CZ',
#  'died': '1914-06-21',
#  'diedCity': 'Vienna',
#  'diedCountry': 'Austria',
#  'diedCountryCode': 'AT',
#  'firstname': 'Bertha',
#  'gender': 'female',
#  'id': '468',
#  'prizes': [{'affiliations': [[]],
#              'category': 'peace',
#              'motivation': '"for her audacity to oppose the horrors of war"',
#              'share': '1',
#              'year': '1905'}],
#  'surname': 'von Suttner'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3d1c'),
#  'born': '1858-11-20',
#  'bornCity': 'Mårbacka',
#  'bornCountry': 'Sweden',
#  'bornCountryCode': 'SE',
#  'died': '1940-03-16',
#  'diedCity': 'Mårbacka',
#  'diedCountry': 'Sweden',
#  'diedCountryCode': 'SE',
#  'firstname': 'Selma',
#  'gender': 'female',
#  'id': '579',
#  'prizes': [{'affiliations': [[]],
#              'category': 'literature',
#              'motivation': '"in appreciation of the lofty idealism, vivid '
#                            'imagination and spiritual perception that '
#                            'characterize her writings"',
#              'share': '1',
#              'year': '1909'}],
#  'surname': 'Lagerlöf'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3d2c'),
#  'born': '1871-09-27',
#  'bornCity': 'Nuoro, Sardinia',
#  'bornCountry': 'Italy',
#  'bornCountryCode': 'IT',
#  'died': '1936-08-15',
#  'diedCity': 'Rome',
#  'diedCountry': 'Italy',
#  'diedCountryCode': 'IT',
#  'firstname': 'Grazia',
#  'gender': 'female',
#  'id': '597',
#  'prizes': [{'affiliations': [[]],
#              'category': 'literature',
#              'motivation': '"for her idealistically inspired writings which '
#                            'with plastic clarity picture the life on her '
#                            'native island and with depth and sympathy deal '
#                            'with human problems in general"',
#              'share': '1',
#              'year': '1926'}],
#  'surname': 'Deledda'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3d2e'),
#  'born': '1882-05-20',
#  'bornCity': 'Kalundborg',
#  'bornCountry': 'Denmark',
#  'bornCountryCode': 'DK',
#  'died': '1949-06-10',
#  'diedCity': 'Lillehammer',
#  'diedCountry': 'Norway',
#  'diedCountryCode': 'NO',
#  'firstname': 'Sigrid',
#  'gender': 'female',
#  'id': '601',
#  'prizes': [{'affiliations': [[]],
#              'category': 'literature',
#              'motivation': '"principally for her powerful descriptions of '
#                            'Northern life during the Middle Ages"',
#              'share': '1',
#              'year': '1928'}],
#  'surname': 'Undset'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3cce'),
#  'born': '1860-09-06',
#  'bornCity': 'Cedarville, IL',
#  'bornCountry': 'USA',
#  'bornCountryCode': 'US',
#  'died': '1935-05-21',
#  'diedCity': 'Chicago, IL',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'Jane',
#  'gender': 'female',
#  'id': '496',
#  'prizes': [{'affiliations': [[]],
#              'category': 'peace',
#              'motivation': '"for their assiduous effort to revive the ideal of '
#                            'peace and to rekindle the spirit of peace in their '
#                            'own nation and in the whole of mankind"',
#              'share': '2',
#              'year': '1931'}],
#  'surname': 'Addams'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3ba2'),
#  'born': '1897-09-12',
#  'bornCity': 'Paris',
#  'bornCountry': 'France',
#  'bornCountryCode': 'FR',
#  'died': '1956-03-17',
#  'diedCity': 'Paris',
#  'diedCountry': 'France',
#  'diedCountryCode': 'FR',
#  'firstname': 'Irène',
#  'gender': 'female',
#  'id': '194',
#  'prizes': [{'affiliations': [{'city': 'Paris',
#                                'country': 'France',
#                                'name': 'Institut du Radium'}],
#              'category': 'chemistry',
#              'motivation': '"in recognition of their synthesis of new '
#                            'radioactive elements"',
#              'share': '2',
#              'year': '1935'}],
#  'surname': 'Joliot-Curie'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3d37'),
#  'born': '1892-06-26',
#  'bornCity': 'Hillsboro, WV',
#  'bornCountry': 'USA',
#  'bornCountryCode': 'US',
#  'died': '1973-03-06',
#  'diedCity': 'Danby, VT',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'Pearl',
#  'gender': 'female',
#  'id': '610',
#  'prizes': [{'affiliations': [[]],
#              'category': 'literature',
#              'motivation': '"for her rich and truly epic descriptions of '
#                            'peasant life in China and for her biographical '
#                            'masterpieces"',
#              'share': '1',
#              'year': '1938'}],
#  'surname': 'Buck'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3d3a'),
#  'born': '1889-04-07',
#  'bornCity': 'Vicuña',
#  'bornCountry': 'Chile',
#  'bornCountryCode': 'CL',
#  'died': '1957-01-10',
#  'diedCity': 'Hempstead, NY',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'Gabriela',
#  'gender': 'female',
#  'id': '615',
#  'prizes': [{'affiliations': [[]],
#              'category': 'literature',
#              'motivation': '"for her lyric poetry which, inspired by powerful '
#                            'emotions, has made her name a symbol of the '
#                            'idealistic aspirations of the entire Latin '
#                            'American world"',
#              'share': '1',
#              'year': '1945'}],
#  'surname': 'Mistral'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3cd7'),
#  'born': '1867-01-08',
#  'bornCity': 'Jamaica Plain, MA (now Boston, MA)',
#  'bornCountry': 'USA',
#  'bornCountryCode': 'US',
#  'died': '1961-01-09',
#  'diedCity': 'Cambridge, MA',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'Emily Greene',
#  'gender': 'female',
#  'id': '506',
#  'prizes': [{'affiliations': [[]],
#              'category': 'peace',
#              'motivation': '"for her lifelong work for the cause of peace"',
#              'share': '2',
#              'year': '1946'}],
#  'surname': 'Balch'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3c37'),
#  'born': '1896-08-15',
#  'bornCity': 'Prague',
#  'bornCountry': 'Austria-Hungary (now Czech Republic)',
#  'bornCountryCode': 'CZ',
#  'died': '1957-10-26',
#  'diedCity': 'St. Louis, MO',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'Gerty',
#  'gender': 'female',
#  'id': '344',
#  'prizes': [{'affiliations': [{'city': 'St. Louis, MO',
#                                'country': 'USA',
#                                'name': 'Washington University'}],
#              'category': 'medicine',
#              'motivation': '"for their discovery of the course of the '
#                            'catalytic conversion of glycogen"',
#              'share': '4',
#              'year': '1947'}],
#  'surname': 'Cori'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3b32'),
#  'born': '1906-06-28',
#  'bornCity': 'Kattowitz (now Katowice)',
#  'bornCountry': 'Germany (now Poland)',
#  'bornCountryCode': 'PL',
#  'died': '1972-02-20',
#  'diedCity': 'San Diego, CA',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'Maria',
#  'gender': 'female',
#  'id': '79',
#  'prizes': [{'affiliations': [{'city': 'San Diego, CA',
#                                'country': 'USA',
#                                'name': 'University of California'}],
#              'category': 'physics',
#              'motivation': '"for their discoveries concerning nuclear shell '
#                            'structure"',
#              'share': '4',
#              'year': '1963'}],
#  'surname': 'Goeppert Mayer'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3bc6'),
#  'born': '1910-05-12',
#  'bornCity': 'Cairo',
#  'bornCountry': 'Egypt',
#  'bornCountryCode': 'EG',
#  'died': '1994-07-29',
#  'diedCity': 'Shipston-on-Stour',
#  'diedCountry': 'United Kingdom',
#  'diedCountryCode': 'GB',
#  'firstname': 'Dorothy Crowfoot',
#  'gender': 'female',
#  'id': '230',
#  'prizes': [{'affiliations': [{'city': 'Oxford',
#                                'country': 'United Kingdom',
#                                'name': 'University of Oxford, Royal Society'}],
#              'category': 'chemistry',
#              'motivation': '"for her determinations by X-ray techniques of the '
#                            'structures of important biochemical substances"',
#              'share': '1',
#              'year': '1964'}],
#  'surname': 'Hodgkin'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3d50'),
#  'born': '1891-12-10',
#  'bornCity': 'Berlin',
#  'bornCountry': 'Germany',
#  'bornCountryCode': 'DE',
#  'died': '1970-05-12',
#  'diedCity': 'Stockholm',
#  'diedCountry': 'Sweden',
#  'diedCountryCode': 'SE',
#  'firstname': 'Nelly',
#  'gender': 'female',
#  'id': '640',
#  'prizes': [{'affiliations': [[]],
#              'category': 'literature',
#              'motivation': '"for her outstanding lyrical and dramatic writing, '
#                            "which interprets Israel's destiny with touching "
#                            'strength "',
#              'share': '2',
#              'year': '1966'}],
#  'surname': 'Sachs'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3cf2'),
#  'born': '1943-05-22',
#  'bornCity': 'Belfast',
#  'bornCountry': 'Northern Ireland',
#  'bornCountryCode': 'GB',
#  'died': '2020-03-17',
#  'diedCity': 'Belfast',
#  'diedCountry': 'Northern Ireland',
#  'diedCountryCode': 'GB',
#  'firstname': 'Betty',
#  'gender': 'female',
#  'id': '535',
#  'prizes': [{'affiliations': [[]],
#              'category': 'peace',
#              'motivation': '"for the courageous efforts in founding a movement '
#                            'to put an end to the violent conflict in Northern '
#                            'Ireland"',
#              'share': '2',
#              'year': '1976'}],
#  'surname': 'Williams'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3cf3'),
#  'born': '1944-01-27',
#  'bornCity': 'Belfast',
#  'bornCountry': 'Northern Ireland',
#  'bornCountryCode': 'GB',
#  'died': '0000-00-00',
#  'firstname': 'Mairead',
#  'gender': 'female',
#  'id': '536',
#  'prizes': [{'affiliations': [[]],
#              'category': 'peace',
#              'motivation': '"for the courageous efforts in founding a movement '
#                            'to put an end to the violent conflict in Northern '
#                            'Ireland"',
#              'share': '2',
#              'year': '1976'}],
#  'surname': 'Corrigan'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3c7c'),
#  'born': '1921-07-19',
#  'bornCity': 'New York, NY',
#  'bornCountry': 'USA',
#  'bornCountryCode': 'US',
#  'died': '2011-05-30',
#  'diedCity': 'New York, NY',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'Rosalyn',
#  'gender': 'female',
#  'id': '413',
#  'prizes': [{'affiliations': [{'city': 'Bronx, NY',
#                                'country': 'USA',
#                                'name': 'Veterans Administration Hospital'}],
#              'category': 'medicine',
#              'motivation': '"for the development of radioimmunoassays of '
#                            'peptide hormones"',
#              'share': '2',
#              'year': '1977'}],
#  'surname': 'Yalow'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3cf7'),
#  'born': '1910-08-26',
#  'bornCity': 'Uskup (now Skopje)',
#  'bornCountry': 'Ottoman Empire (now North Macedonia)',
#  'bornCountryCode': 'MK',
#  'died': '1997-09-05',
#  'diedCity': 'Calcutta',
#  'diedCountry': 'India',
#  'diedCountryCode': 'IN',
#  'firstname': 'Anjezë Gonxhe',
#  'gender': 'female',
#  'id': '540',
#  'prizes': [{'affiliations': [[]],
#              'category': 'peace',
#              'motivation': '"for her work for bringing help to suffering '
#                            'humanity"',
#              'share': '1',
#              'year': '1979'}],
#  'surname': 'Bojaxhiu'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3cf9'),
#  'born': '1902-01-31',
#  'bornCity': 'Uppsala',
#  'bornCountry': 'Sweden',
#  'bornCountryCode': 'SE',
#  'died': '1986-02-01',
#  'diedCity': 'Stockholm',
#  'diedCountry': 'Sweden',
#  'diedCountryCode': 'SE',
#  'firstname': 'Alva',
#  'gender': 'female',
#  'id': '543',
#  'prizes': [{'affiliations': [[]],
#              'category': 'peace',
#              'motivation': '"for their work for disarmament and nuclear and '
#                            'weapon-free zones"',
#              'share': '2',
#              'year': '1982'}],
#  'surname': 'Myrdal'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3c8b'),
#  'born': '1902-06-16',
#  'bornCity': 'Hartford, CT',
#  'bornCountry': 'USA',
#  'bornCountryCode': 'US',
#  'died': '1992-09-02',
#  'diedCity': 'Huntington, NY',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'Barbara',
#  'gender': 'female',
#  'id': '428',
#  'prizes': [{'affiliations': [{'city': 'Cold Spring Harbor, NY',
#                                'country': 'USA',
#                                'name': 'Cold Spring Harbor Laboratory'}],
#              'category': 'medicine',
#              'motivation': '"for her discovery of mobile genetic elements"',
#              'share': '1',
#              'year': '1983'}],
#  'surname': 'McClintock'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3c92'),
#  'born': '1909-04-22',
#  'bornCity': 'Turin',
#  'bornCountry': 'Italy',
#  'bornCountryCode': 'IT',
#  'died': '2012-12-30',
#  'diedCity': 'Rome',
#  'diedCountry': 'Italy',
#  'diedCountryCode': 'IT',
#  'firstname': 'Rita',
#  'gender': 'female',
#  'id': '435',
#  'prizes': [{'affiliations': [{'city': 'Rome',
#                                'country': 'Italy',
#                                'name': 'Institute of Cell Biology of the '
#                                        'C.N.R.'}],
#              'category': 'medicine',
#              'motivation': '"for their discoveries of growth factors"',
#              'share': '2',
#              'year': '1986'}],
#  'surname': 'Levi-Montalcini'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3c95'),
#  'born': '1918-01-23',
#  'bornCity': 'New York, NY',
#  'bornCountry': 'USA',
#  'bornCountryCode': 'US',
#  'died': '1999-02-21',
#  'diedCity': 'Chapel Hill, NC',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'Gertrude B.',
#  'gender': 'female',
#  'id': '438',
#  'prizes': [{'affiliations': [{'city': 'Research Triangle Park, NC',
#                                'country': 'USA',
#                                'name': 'Wellcome Research Laboratories'}],
#              'category': 'medicine',
#              'motivation': '"for their discoveries of important principles for '
#                            'drug treatment"',
#              'share': '3',
#              'year': '1988'}],
#  'surname': 'Elion'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3d03'),
#  'born': '1945-06-19',
#  'bornCity': 'Rangoon (now Yangon)',
#  'bornCountry': 'Burma (now Myanmar)',
#  'bornCountryCode': 'MM',
#  'died': '0000-00-00',
#  'firstname': 'Aung San Suu Kyi',
#  'gender': 'female',
#  'id': '553',
#  'prizes': [{'affiliations': [[]],
#              'category': 'peace',
#              'motivation': '"for her non-violent struggle for democracy and '
#                            'human rights"',
#              'share': '1',
#              'year': '1991'}]}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3d6a'),
#  'born': '1923-11-20',
#  'bornCity': 'Springs',
#  'bornCountry': 'South Africa',
#  'bornCountryCode': 'ZA',
#  'died': '2014-07-13',
#  'diedCity': 'Johannesburg',
#  'diedCountry': 'South Africa',
#  'diedCountryCode': 'ZA',
#  'firstname': 'Nadine',
#  'gender': 'female',
#  'id': '668',
#  'prizes': [{'affiliations': [[]],
#              'category': 'literature',
#              'motivation': '"who through her magnificent epic writing has - in '
#                            'the words of Alfred Nobel - been of very great '
#                            'benefit to humanity"',
#              'share': '1',
#              'year': '1991'}],
#  'surname': 'Gordimer'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3d04'),
#  'born': '1959-01-09',
#  'bornCity': 'Aldea Chimel',
#  'bornCountry': 'Guatemala',
#  'bornCountryCode': 'GT',
#  'died': '0000-00-00',
#  'firstname': 'Rigoberta',
#  'gender': 'female',
#  'id': '554',
#  'prizes': [{'affiliations': [[]],
#              'category': 'peace',
#              'motivation': '"for her struggle for social justice and '
#                            'ethno-cultural reconciliation based on respect for '
#                            'the rights of indigenous peoples"',
#              'share': '1',
#              'year': '1992'}],
#  'surname': 'Menchú Tum'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3d6c'),
#  'born': '1931-02-18',
#  'bornCity': 'Lorain, OH',
#  'bornCountry': 'USA',
#  'bornCountryCode': 'US',
#  'died': '2019-08-05',
#  'diedCity': 'New York, NY',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'Toni',
#  'gender': 'female',
#  'id': '670',
#  'prizes': [{'affiliations': [[]],
#              'category': 'literature',
#              'motivation': '"who in novels characterized by visionary force '
#                            'and poetic import, gives life to an essential '
#                            'aspect of American reality"',
#              'share': '1',
#              'year': '1993'}],
#  'surname': 'Morrison'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3ca4'),
#  'born': '1942-10-20',
#  'bornCity': 'Magdeburg',
#  'bornCountry': 'Germany',
#  'bornCountryCode': 'DE',
#  'died': '0000-00-00',
#  'firstname': 'Christiane',
#  'gender': 'female',
#  'id': '453',
#  'prizes': [{'affiliations': [{'city': 'Tübingen',
#                                'country': 'Germany',
#                                'name': 'Max-Planck-Institut für '
#                                        'Entwicklungsbiologie'}],
#              'category': 'medicine',
#              'motivation': '"for their discoveries concerning the genetic '
#                            'control of early embryonic development"',
#              'share': '3',
#              'year': '1995'}],
#  'surname': 'Nüsslein-Volhard'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3d6f'),
#  'born': '1923-07-02',
#  'bornCity': 'Bnin (now Kórnik)',
#  'bornCountry': 'Poland',
#  'bornCountryCode': 'PL',
#  'died': '2012-02-01',
#  'diedCity': 'Kraków',
#  'diedCountry': 'Poland',
#  'diedCountryCode': 'PL',
#  'firstname': 'Wislawa',
#  'gender': 'female',
#  'id': '673',
#  'prizes': [{'affiliations': [[]],
#              'category': 'literature',
#              'motivation': '"for poetry that with ironic precision allows the '
#                            'historical and biological context to come to light '
#                            'in fragments of human reality"',
#              'share': '1',
#              'year': '1996'}],
#  'surname': 'Szymborska'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3d0f'),
#  'born': '1950-10-09',
#  'bornCity': 'Putney, VT',
#  'bornCountry': 'USA',
#  'bornCountryCode': 'US',
#  'died': '0000-00-00',
#  'firstname': 'Jody',
#  'gender': 'female',
#  'id': '565',
#  'prizes': [{'affiliations': [[]],
#              'category': 'peace',
#              'motivation': '"for their work for the banning and clearing of '
#                            'anti-personnel mines"',
#              'share': '2',
#              'year': '1997'}],
#  'surname': 'Williams'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3dd3'),
#  'born': '1947-06-21',
#  'bornCity': 'Hamadan',
#  'bornCountry': 'Iran',
#  'bornCountryCode': 'IR',
#  'died': '0000-00-00',
#  'firstname': 'Shirin',
#  'gender': 'female',
#  'id': '773',
#  'prizes': [{'affiliations': [[]],
#              'category': 'peace',
#              'motivation': '"for her efforts for democracy and human rights. '
#                            'She has focused especially on the struggle for the '
#                            'rights of women and children"',
#              'share': '1',
#              'year': '2003'}],
#  'surname': 'Ebadi'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3dd5'),
#  'born': '1947-01-29',
#  'bornCity': 'Seattle, WA',
#  'bornCountry': 'USA',
#  'bornCountryCode': 'US',
#  'died': '0000-00-00',
#  'firstname': 'Linda B.',
#  'gender': 'female',
#  'id': '775',
#  'prizes': [{'affiliations': [{'city': 'Seattle, WA',
#                                'country': 'USA',
#                                'name': 'Fred Hutchinson Cancer Research '
#                                        'Center'}],
#              'category': 'medicine',
#              'motivation': '"for their discoveries of odorant receptors and '
#                            'the organization of the olfactory system"',
#              'share': '2',
#              'year': '2004'}],
#  'surname': 'Buck'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3ddc'),
#  'born': '1946-10-20',
#  'bornCity': 'Mürzzuschlag',
#  'bornCountry': 'Austria',
#  'bornCountryCode': 'AT',
#  'died': '0000-00-00',
#  'firstname': 'Elfriede',
#  'gender': 'female',
#  'id': '782',
#  'prizes': [{'affiliations': [[]],
#              'category': 'literature',
#              'motivation': '"for her musical flow of voices and counter-voices '
#                            'in novels and plays that with extraordinary '
#                            "linguistic zeal reveal the absurdity of society's "
#                            'clich&eacute;s and their subjugating power"',
#              'share': '1',
#              'year': '2004'}],
#  'surname': 'Jelinek'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3ddd'),
#  'born': '1940-04-01',
#  'bornCity': 'Nyeri',
#  'bornCountry': 'Kenya',
#  'bornCountryCode': 'KE',
#  'died': '2011-09-25',
#  'diedCity': 'Nairobi',
#  'diedCountry': 'Kenya',
#  'diedCountryCode': 'KE',
#  'firstname': 'Wangari',
#  'gender': 'female',
#  'id': '783',
#  'prizes': [{'affiliations': [[]],
#              'category': 'peace',
#              'motivation': '"for her contribution to sustainable development, '
#                            'democracy and peace"',
#              'share': '1',
#              'year': '2004'}],
#  'surname': 'Maathai'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3dfc'),
#  'born': '1919-10-22',
#  'bornCity': 'Kermanshah',
#  'bornCountry': 'Persia (now Iran)',
#  'bornCountryCode': 'IR',
#  'died': '2013-11-17',
#  'diedCity': 'London',
#  'diedCountry': 'United Kingdom',
#  'diedCountryCode': 'GB',
#  'firstname': 'Doris',
#  'gender': 'female',
#  'id': '817',
#  'prizes': [{'affiliations': [[]],
#              'category': 'literature',
#              'motivation': '"that epicist of the female experience, who with '
#                            'scepticism, fire and visionary power has subjected '
#                            'a divided civilisation to scrutiny"',
#              'share': '1',
#              'year': '2007'}],
#  'surname': 'Lessing'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3e03'),
#  'born': '1947-07-30',
#  'bornCity': 'Paris',
#  'bornCountry': 'France',
#  'bornCountryCode': 'FR',
#  'died': '0000-00-00',
#  'firstname': 'Françoise',
#  'gender': 'female',
#  'id': '824',
#  'prizes': [{'affiliations': [{'city': 'Paris',
#                                'country': 'France',
#                                'name': 'Regulation of Retroviral Infections '
#                                        'Unit, Virology Department, Institut '
#                                        'Pasteur'}],
#              'category': 'medicine',
#              'motivation': '"for their discovery of human immunodeficiency '
#                            'virus"',
#              'share': '4',
#              'year': '2008'}],
#  'surname': 'Barré-Sinoussi'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3e0e'),
#  'born': '1948-11-26',
#  'bornCity': 'Hobart, Tasmania',
#  'bornCountry': 'Australia',
#  'bornCountryCode': 'AU',
#  'died': '0000-00-00',
#  'firstname': 'Elizabeth H.',
#  'gender': 'female',
#  'id': '835',
#  'prizes': [{'affiliations': [{'city': 'San Francisco, CA',
#                                'country': 'USA',
#                                'name': 'University of California'}],
#              'category': 'medicine',
#              'motivation': '"for the discovery of how chromosomes are '
#                            'protected by telomeres and the enzyme telomerase"',
#              'share': '3',
#              'year': '2009'}],
#  'surname': 'Blackburn'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3e0f'),
#  'born': '1961-04-15',
#  'bornCity': 'San Diego, CA',
#  'bornCountry': 'USA',
#  'bornCountryCode': 'US',
#  'died': '0000-00-00',
#  'firstname': 'Carol W.',
#  'gender': 'female',
#  'id': '836',
#  'prizes': [{'affiliations': [{'city': 'Baltimore, MD',
#                                'country': 'USA',
#                                'name': 'Johns Hopkins University School of '
#                                        'Medicine'}],
#              'category': 'medicine',
#              'motivation': '"for the discovery of how chromosomes are '
#                            'protected by telomeres and the enzyme telomerase"',
#              'share': '3',
#              'year': '2009'}],
#  'surname': 'Greider'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3e16'),
#  'born': '1939-06-22',
#  'bornCity': 'Jerusalem',
#  'bornCountry': 'British Mandate of Palestine (now Israel)',
#  'bornCountryCode': 'IL',
#  'died': '0000-00-00',
#  'firstname': 'Ada E.',
#  'gender': 'female',
#  'id': '843',
#  'prizes': [{'affiliations': [{'city': 'Rehovot',
#                                'country': 'Israel',
#                                'name': 'Weizmann Institute of Science'}],
#              'category': 'chemistry',
#              'motivation': '"for studies of the structure and function of the '
#                            'ribosome"',
#              'share': '3',
#              'year': '2009'}],
#  'surname': 'Yonath'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3e17'),
#  'born': '1953-08-17',
#  'bornCity': 'Nitzkydorf, Banat',
#  'bornCountry': 'Romania',
#  'bornCountryCode': 'RO',
#  'died': '0000-00-00',
#  'firstname': 'Herta',
#  'gender': 'female',
#  'id': '844',
#  'prizes': [{'affiliations': [[]],
#              'category': 'literature',
#              'motivation': '"who, with the concentration of poetry and the '
#                            'frankness of prose, depicts the landscape of the '
#                            'dispossessed"',
#              'share': '1',
#              'year': '2009'}],
#  'surname': 'Müller'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3e19'),
#  'born': '1933-08-07',
#  'bornCity': 'Los Angeles, CA',
#  'bornCountry': 'USA',
#  'bornCountryCode': 'US',
#  'died': '2012-06-12',
#  'diedCity': 'Bloomington, IN',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'Elinor',
#  'gender': 'female',
#  'id': '846',
#  'prizes': [{'affiliations': [{'city': 'Bloomington, IN',
#                                'country': 'USA',
#                                'name': 'Indiana University'},
#                               {'city': 'Tempe, AZ',
#                                'country': 'USA',
#                                'name': 'Arizona State University'}],
#              'category': 'economics',
#              'motivation': '"for her analysis of economic governance, '
#                            'especially the commons"',
#              'share': '2',
#              'year': '2009'}],
#  'surname': 'Ostrom'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3e2e'),
#  'born': '1938-10-29',
#  'bornCity': 'Monrovia',
#  'bornCountry': 'Liberia',
#  'bornCountryCode': 'LR',
#  'died': '0000-00-00',
#  'firstname': 'Ellen',
#  'gender': 'female',
#  'id': '869',
#  'prizes': [{'affiliations': [[]],
#              'category': 'peace',
#              'motivation': '"for their non-violent struggle for the safety of '
#                            'women and for women\x92s rights to full '
#                            'participation in peace-building work"',
#              'share': '3',
#              'year': '2011'}],
#  'surname': 'Johnson Sirleaf'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3e2f'),
#  'born': '1972-02-01',
#  'bornCity': 'Monrovia',
#  'bornCountry': 'Liberia',
#  'bornCountryCode': 'LR',
#  'died': '0000-00-00',
#  'firstname': 'Leymah',
#  'gender': 'female',
#  'id': '870',
#  'prizes': [{'affiliations': [[]],
#              'category': 'peace',
#              'motivation': '"for their non-violent struggle for the safety of '
#                            'women and for women\x92s rights to full '
#                            'participation in peace-building work"',
#              'share': '3',
#              'year': '2011'}],
#  'surname': 'Gbowee'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3e30'),
#  'born': '1979-02-07',
#  'bornCity': "Ta'izz",
#  'bornCountry': 'Yemen',
#  'bornCountryCode': 'YE',
#  'died': '0000-00-00',
#  'firstname': 'Tawakkol',
#  'gender': 'female',
#  'id': '871',
#  'prizes': [{'affiliations': [[]],
#              'category': 'peace',
#              'motivation': '"for their non-violent struggle for the safety of '
#                            'women and for women\x92s rights to full '
#                            'participation in peace-building work"',
#              'share': '3',
#              'year': '2011'}],
#  'surname': 'Karman'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3e45'),
#  'born': '1931-07-10',
#  'bornCity': 'Wingham',
#  'bornCountry': 'Canada',
#  'bornCountryCode': 'CA',
#  'died': '0000-00-00',
#  'firstname': 'Alice',
#  'gender': 'female',
#  'id': '892',
#  'prizes': [{'affiliations': [[]],
#              'category': 'literature',
#              'motivation': '"master of the contemporary short story"',
#              'share': '1',
#              'year': '2013'}],
#  'surname': 'Munro'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3e4b'),
#  'born': '1963-01-04',
#  'bornCity': 'Fosnavåg',
#  'bornCountry': 'Norway',
#  'bornCountryCode': 'NO',
#  'died': '0000-00-00',
#  'firstname': 'May-Britt',
#  'gender': 'female',
#  'id': '904',
#  'prizes': [{'affiliations': [{'city': 'Trondheim',
#                                'country': 'Norway',
#                                'name': 'Norwegian University of Science and '
#                                        'Technology (NTNU)'}],
#              'category': 'medicine',
#              'motivation': '"for their discoveries of cells that constitute a '
#                            'positioning system in the brain"',
#              'share': '4',
#              'year': '2014'}],
#  'surname': 'Moser'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3e55'),
#  'born': '1997-07-12',
#  'bornCity': 'Mingora',
#  'bornCountry': 'Pakistan',
#  'bornCountryCode': 'PK',
#  'died': '0000-00-00',
#  'firstname': 'Malala',
#  'gender': 'female',
#  'id': '914',
#  'prizes': [{'affiliations': [[]],
#              'category': 'peace',
#              'motivation': '"for their struggle against the suppression of '
#                            'children and young people and for the right of all '
#                            'children to education"',
#              'share': '2',
#              'year': '2014'}],
#  'surname': 'Yousafzai'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3e59'),
#  'born': '1930-12-30',
#  'bornCity': 'Zhejiang Ningbo',
#  'bornCountry': 'China',
#  'bornCountryCode': 'CN',
#  'died': '0000-00-00',
#  'firstname': 'Youyou',
#  'gender': 'female',
#  'id': '918',
#  'prizes': [{'affiliations': [{'city': 'Beijing',
#                                'country': 'China',
#                                'name': 'China Academy of Traditional Chinese '
#                                        'Medicine'}],
#              'category': 'medicine',
#              'motivation': '"for her discoveries concerning a novel therapy '
#                            'against Malaria"',
#              'share': '2',
#              'year': '2015'}],
#  'surname': 'Tu'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3e5f'),
#  'born': '1948-05-31',
#  'bornCity': 'Ivano-Frankivsk',
#  'bornCountry': 'Ukraine',
#  'bornCountryCode': 'UA',
#  'died': '0000-00-00',
#  'firstname': 'Svetlana',
#  'gender': 'female',
#  'id': '924',
#  'prizes': [{'affiliations': [[]],
#              'category': 'literature',
#              'motivation': '"for her polyphonic writings, a monument to '
#                            'suffering and courage in our time"',
#              'share': '1',
#              'year': '2015'}],
#  'surname': 'Alexievich'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3e7d'),
#  'born': '1959-05-27',
#  'bornCity': 'Guelph',
#  'bornCountry': 'Canada',
#  'bornCountryCode': 'CA',
#  'died': '0000-00-00',
#  'firstname': 'Donna',
#  'gender': 'female',
#  'id': '962',
#  'prizes': [{'affiliations': [{'city': 'Waterloo',
#                                'country': 'Canada',
#                                'name': 'University of Waterloo'}],
#              'category': 'physics',
#              'motivation': '"for their method of generating high-intensity, '
#                            'ultra-short optical pulses"',
#              'overallMotivation': '"for groundbreaking inventions in the field '
#                                   'of laser physics"',
#              'share': '4',
#              'year': '2018'}],
#  'surname': 'Strickland'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3e7e'),
#  'born': '1956-07-25',
#  'bornCity': 'Pittsburgh, PA',
#  'bornCountry': 'USA',
#  'bornCountryCode': 'US',
#  'died': '0000-00-00',
#  'firstname': 'Frances H.',
#  'gender': 'female',
#  'id': '963',
#  'prizes': [{'affiliations': [{'city': 'Pasadena, CA',
#                                'country': 'USA',
#                                'name': 'California Institute of Technology '
#                                        '(Caltech)'}],
#              'category': 'chemistry',
#              'motivation': '"for the directed evolution of enzymes"',
#              'share': '2',
#              'year': '2018'}],
#  'surname': 'Arnold'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3e82'),
#  'born': '1993-00-00',
#  'bornCity': 'Kojo',
#  'bornCountry': 'Iraq',
#  'bornCountryCode': 'IQ',
#  'died': '0000-00-00',
#  'firstname': 'Nadia',
#  'gender': 'female',
#  'id': '967',
#  'prizes': [{'affiliations': [[]],
#              'category': 'peace',
#              'motivation': '"for their efforts to end the use of sexual '
#                            'violence as a weapon of war and armed conflict"',
#              'share': '2',
#              'year': '2018'}],
#  'surname': 'Murad'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3e8e'),
#  'born': '1962-01-29',
#  'bornCity': 'Sulechów',
#  'bornCountry': 'Poland',
#  'bornCountryCode': 'PL',
#  'died': '0000-00-00',
#  'firstname': 'Olga',
#  'gender': 'female',
#  'id': '979',
#  'prizes': [{'affiliations': [[]],
#              'category': 'literature',
#              'motivation': '"for a narrative imagination that with '
#                            'encyclopedic passion represents the crossing of '
#                            'boundaries as a form of life"',
#              'share': '1',
#              'year': '2018'}],
#  'surname': 'Tokarczuk'}
# {'_id': ObjectId('5ed53712ff2a824fbb2b3e92'),
#  'born': '1972-10-25',
#  'bornCity': 'Paris',
#  'bornCountry': 'France',
#  'bornCountryCode': 'FR',
#  'died': '0000-00-00',
#  'firstname': 'Esther',
#  'gender': 'female',
#  'id': '983',
#  'prizes': [{'affiliations': [{'city': 'Cambridge, MA',
#                                'country': 'USA',
#                                'name': 'Massachusetts Institute of Technology '
#                                        '(MIT)'}],
#              'category': 'economics',
#              'motivation': '"for their experimental approach to alleviating '
#                            'global poverty"',
#              'share': '3',
#              'year': '2019'}],
#  'surname': 'Duflo'}
